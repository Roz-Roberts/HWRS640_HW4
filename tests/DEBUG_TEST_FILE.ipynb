# %%
import minicamels as mc
import pandas as pd

ds = mc.MiniCamels("C:\\Users\\roswe\\Desktop\\minicamels\\data")

basins = ds.basins().iloc[:, 0].to_numpy()  # Array of all basin ID's - ID's ONLY NOT NAMES

attrs = ds.attributes()

basin_attrs = attrs[attrs.index == basins[0]]

basin_attrs

ts = ds.load_all()

print(ts)
# Out:
# <xarray.Dataset> Size: 13MB
# Dimensions:  (basin: 50, time: 10957)
# Coordinates:
#   * basin    (basin) StringDType(na_object=nan) 800B '01013500' ... '14325000'
#   * time     (time) datetime64[ns] 88kB 1980-10-01 1980-10-02 ... 2010-09-30
# Data variables:
#     prcp     (basin, time) float32 2MB 3.1 4.24 8.02 15.27 ... 0.0 0.0 0.0 0.0
#     tmax     (basin, time) float32 2MB 10.05 15.82 15.86 ... 21.31 22.73 24.84
#     tmin     (basin, time) float32 2MB 2.11 5.24 7.81 3.66 ... 13.98 12.59 13.02
#     srad     (basin, time) float32 2MB 192.6 206.3 165.4 ... 285.7 353.1 369.5
#     vp       (basin, time) float32 2MB 711.3 898.6 ... 1.286e+03 1.289e+03
#     qobs     (basin, time) float32 2MB 0.5528 0.5626 0.5604 ... 0.1877 0.1877
# Attributes:
#     Conventions:  CF-1.8
#     basin_id:     01013500
#     basin_name:   Fish River near Fort Kent, Maine
#     area_km2:     2252.7
#     lat:          47.23739
#     lon:          -68.58264
#     huc02:        01
# ...
